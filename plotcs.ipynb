# %%
# read results_cora.csv

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# read data
df = pd.read_csv('results_cs.csv')
# remove column 'Unnamed: 0'
df = df.drop('Unnamed: 0', axis=1)
print(df.head())
# Out:
#    Accuracy  Precision    Recall  F1_Score  Alpha  Epsilon  Attention
# 0     0.610   0.583567  0.585649  0.582900    0.5      0.5          1
# 1     0.512   0.510158  0.505532  0.498099    0.5      0.5          0
# 2     0.617   0.588202  0.590820  0.588354    0.5      0.6          1
# 3     0.515   0.513049  0.508155  0.501045    0.5      0.6          0
# 4     0.617   0.587417  0.591226  0.588102    0.5      0.7          1

# %%
# metrics to show
# groupby 'Attention'
# mean and std for each group

# groupby 'Attention'
grouped = df.groupby('Attention')

# mean and std for each group
mean = grouped.mean()
std = grouped.std()

print(mean)
print(std)

# export to csv
mean.to_csv('mean_cs.csv')
std.to_csv('std_cs.csv')
# Out:
#            Accuracy  Precision    Recall  F1_Score  Alpha  Epsilon
# Attention
# 0           0.51384   0.511728  0.506327  0.499276    0.7      0.7
# 1           0.61896   0.589427  0.591709  0.589654    0.7      0.7
#            Accuracy  Precision    Recall  F1_Score     Alpha   Epsilon
# Attention
# 0          0.002154   0.002181  0.002237  0.002141  0.144338  0.144338
# 1          0.004158   0.002769  0.002919  0.003120  0.144338  0.144338

# %%
# plot accuracy with hue  = attention
sns.set(style="whitegrid")
plt.figure(figsize=(4, 2), dpi=300)  # Set the figure size to 10x6
ax = sns.lineplot(x=range(0,len(df)), y="Accuracy", data=df, hue="Attention")
plt.title('CiteSeer')
plt.xlabel('Model')
plt.show()

# %%
plt.figure(figsize=(4, 2))
ax = sns.scatterplot(x=range(0,len(df)), y="Accuracy", data=df, hue="Epsilon")
plt.title('Accuracy with and without attention')
plt.xlabel('Model')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., title='Epsilon')
plt.show()

# %%
plt.figure(figsize=(4, 2))
ax = sns.scatterplot(x=range(0,len(df)), y="Accuracy", data=df, hue="Alpha")
sns.scatterplot(x=range(0,len(df)), y="F1_Score", data=df)
plt.title('Accuracy and F1_Score with and without attention')
plt.xlabel('Model')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., title='Alpha')
plt.show()
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., title='Epsilon')
plt.show()
